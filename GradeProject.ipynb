# %% [markdown]
# # Get Starting With Import libraries

# %%
import os 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Hbook = pd.read_csv('hotel_booking.csv')
Hbook.sample(6)
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 34797   Resort Hotel            0         14               2017
# 112300    City Hotel            0         71               2017
# 21027   Resort Hotel            0          5               2016
# 34637   Resort Hotel            0          0               2017
# 110556    City Hotel            0         79               2017
# 111794    City Hotel            0         85               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 34797               April                        14
# 112300                May                        20
# 21027            February                         8
# 34637               March                        13
# 110556              April                        17
# 111794                May                        19
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 34797                           4                        0
# ...

# %%
### we will use this code's to see ALL Column's
###1-usecols=[9,10,11]) --to read this coulmns--
   #  ---------------------------------------- #
###2-pd.set_option('display.max_columns',36)--

# %%
Hbook.shape
# Out:
# (119390, 36)

# %%
pd.set_option('display.max_columns',36)

# %%
# Done it's work

Hbook.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  children  babies  \
# 0                        0                     0       2       0.0       0
# ...

# %% [markdown]
# # New technique for EDA For Every Column away

# %%
Hbook.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date', 'name', 'email',
#        'phone-number', 'credit_card'],
#       dtype='object')

# %%
Hbook.nunique()
# Out:
# hotel                                  2
# is_canceled                            2
# lead_time                            479
# arrival_date_year                      3
# arrival_date_month                    12
# arrival_date_week_number              53
# arrival_date_day_of_month             31
# stays_in_weekend_nights               17
# stays_in_week_nights                  35
# adults                                14
# children                               5
# babies                                 5
# meal                                   5
# country                              177
# market_segment                         8
# distribution_channel                   5
# is_repeated_guest                      2
# previous_cancellations                15
# previous_bookings_not_canceled        73
# reserved_room_type                    10
# assigned_room_type                    12
# booking_changes                       21
# deposit_type                           3
# ...

# %%
# here to see the type of hotels 

Hbook['hotel'].value_counts()
# Out:
# City Hotel      79330
# Resort Hotel    40060
# Name: hotel, dtype: int64

# %%
# here to see the dif between meals 

Hbook['meal'].value_counts()
# Out:
# BB           92310
# HB           14463
# SC           10650
# Undefined     1169
# FB             798
# Name: meal, dtype: int64

# %%
Hbook['market_segment'].value_counts()
# Out:
# Online TA        56477
# Offline TA/TO    24219
# Groups           19811
# Direct           12606
# Corporate         5295
# Complementary      743
# Aviation           237
# Undefined            2
# Name: market_segment, dtype: int64

# %%
# here to know the hotel's Strategy of distribution --

Hbook['distribution_channel'].value_counts()
# Out:
# TA/TO        97870
# Direct       14645
# Corporate     6677
# GDS            193
# Undefined        5
# Name: distribution_channel, dtype: int64

# %%
# here we get 3 category's of deposit_type -- 

Hbook['deposit_type'].value_counts()
# Out:
# No Deposit    104641
# Non Refund     14587
# Refundable       162
# Name: deposit_type, dtype: int64

# %%
# here to see who's countery people came from --

Hbook['country'].value_counts()
# Out:
# PRT    48590
# GBR    12129
# FRA    10415
# ESP     8568
# DEU     7287
#        ...
# DJI        1
# BWA        1
# HND        1
# VGB        1
# NAM        1
# Name: country, Length: 177, dtype: int64

# %%
Hbook['total_of_special_requests'].value_counts()
# Out:
# 0    70318
# 1    33226
# 2    12969
# 3     2497
# 4      340
# 5       40
# Name: total_of_special_requests, dtype: int64

# %%
Hbook['customer_type'].value_counts()
# Out:
# Transient          89613
# Transient-Party    25124
# Contract            4076
# Group                577
# Name: customer_type, dtype: int64

# %% [markdown]
# # here we will use seaborn librrary to make chart's

# %%
sns.countplot(data=Hbook,x='hotel')
# Out:
# <AxesSubplot:xlabel='hotel', ylabel='count'>

# %%
sns.countplot(data=Hbook,x='is_canceled', hue='is_repeated_guest')
# Out:
# <AxesSubplot:xlabel='is_canceled', ylabel='count'>

# %%
sns.countplot(data=Hbook,x='hotel', hue='is_canceled')
# Out:
# <AxesSubplot:xlabel='hotel', ylabel='count'>

# %% [markdown]
# # Data Preparation
#
#
#
#
# ### Missing Data

# %%
## to get info 

Hbook.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 36 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
## to know if we get dubs values or not
Hbook.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 119385    False
# 119386    False
# 119387    False
# 119388    False
# 119389    False
# Length: 119390, dtype: bool

# %% [markdown]
# # Here we will know the data type's for all of column's

# %%
## to know the types

Hbook.dtypes
# Out:
# hotel                              object
# is_canceled                         int64
# lead_time                           int64
# arrival_date_year                   int64
# arrival_date_month                 object
# arrival_date_week_number            int64
# arrival_date_day_of_month           int64
# stays_in_weekend_nights             int64
# stays_in_week_nights                int64
# adults                              int64
# children                          float64
# babies                              int64
# meal                               object
# country                            object
# market_segment                     object
# distribution_channel               object
# is_repeated_guest                   int64
# previous_cancellations              int64
# previous_bookings_not_canceled      int64
# reserved_room_type                 object
# assigned_room_type                 object
# booking_changes                     int64
# ...

# %%
## Here we get the time is define as object 
## we going to make it int but before that we will sure from it's null or not

Hbook.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
## Data manipulation and Cleaning 

Hbook.isna().sum().sort_values(ascending = False)[:6]
# Out:
# company            112593
# agent               16340
# country               488
# children                4
# hotel                   0
# booking_changes         0
# dtype: int64

# %%
Hbook['company'].fillna(0, inplace = True)
Hbook['agent'].fillna(0, inplace = True)
Hbook['country'].fillna(0, inplace = True)
Hbook['children'].fillna(0, inplace = True)

# %%
Hbook.isna().sum().sort_values(ascending = False)[:6]
# Out:
# hotel                 0
# is_canceled           0
# assigned_room_type    0
# booking_changes       0
# deposit_type          0
# agent                 0
# dtype: int64

# %%
### Here we can see in Last cell we will done with missing values

# %%
## meals have undefined values ,whic is equal SC
Hbook['meal'].replace("Undefined","SC", inplace=True)

# %%
Hbook['meal'].unique()
# Out:
# array(['BB', 'FB', 'HB', 'SC'], dtype=object)

# %%
## new Technic ---

# %%
Subset = Hbook[(Hbook['children']==0) & (Hbook['adults']==0) & (Hbook['babies']==0)]

# %%
Subset[['children','adults','babies']]
# Out:
#         children  adults  babies
# 2224         0.0       0       0
# 2409         0.0       0       0
# 3181         0.0       0       0
# 3684         0.0       0       0
# 3708         0.0       0       0
# ...          ...     ...     ...
# 115029       0.0       0       0
# 115091       0.0       0       0
# 116251       0.0       0       0
# 116534       0.0       0       0
# 117087       0.0       0       0
#
# [180 rows x 3 columns]

# %%
type(Subset)
# Out:
# pandas.core.frame.DataFrame

# %%
Delete=(Hbook['children']==0) & (Hbook['adults']==0) & (Hbook['babies']==0)

# %%
type(Delete)
# Out:
# pandas.core.series.Series

# %%
Delete
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 119385    False
# 119386    False
# 119387    False
# 119388    False
# 119389    False
# Length: 119390, dtype: bool

# %%
data = Hbook[~Delete]

# %%
data.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  children  babies  \
# 0                        0                     0       2       0.0       0
# ...

# %%
Subset = data[(data['children']==0) & (data['adults']==0) & (data['babies']==0)]

# %%
Subset
# Out:
# Empty DataFrame
# Columns: [hotel, is_canceled, lead_time, arrival_date_year, arrival_date_month, arrival_date_week_number, arrival_date_day_of_month, stays_in_weekend_nights, stays_in_week_nights, adults, children, babies, meal, country, market_segment, distribution_channel, is_repeated_guest, previous_cancellations, previous_bookings_not_canceled, reserved_room_type, assigned_room_type, booking_changes, deposit_type, agent, company, days_in_waiting_list, customer_type, adr, required_car_parking_spaces, total_of_special_requests, reservation_status, reservation_status_date, name, email, phone-number, credit_card]
# Index: []

# %%
data.shape
# Out:
# (119210, 36)

# %%
119390 - 119210
# Out:
# 180

# %%
## all that Code to chek removing this rows

# %% [markdown]
# # Where is people came from

# %%
guest_country = Hbook[Hbook['is_canceled']==0 ]['country'].value_counts().reset_index()
guest_country.columns=['country','Number of guests']

# %%
import plotly.offline as pyo 
import plotly.graph_objs as go
import plotly.express as px

# %%
total_guests = guest_country["Number of guests"].sum()
guest_country["Guests in %"] = round(guest_country["Number of guests"] / total_guests * 100,2)

# %%
guest_country
# Out:
#     country  Number of guests  Guests in %
# 0       PRT             21071        28.19
# 1       GBR              9676        12.95
# 2       FRA              8481        11.35
# 3       ESP              6391         8.55
# 4       DEU              6069         8.12
# ..      ...               ...          ...
# 160     BHR                 1         0.00
# 161     DJI                 1         0.00
# 162     MLI                 1         0.00
# 163     NPL                 1         0.00
# 164     FRO                 1         0.00
#
# [165 rows x 3 columns]

# %%
########################### Now we will Creat tow column's #########################################

# %%
Hbook['all_People'] =  Hbook['children'] + Hbook['babies'] + Hbook['adults']
Hbook['all_Stays'] = Hbook['stays_in_weekend_nights'] + Hbook['stays_in_week_nights']
Hbook
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %% [markdown]
# ## Miss interpreating DATA

# %%
############ The fellow's Cell's WE Did it to know the dif between 
############ city hotels and resort hotels about price
############ from arrival date month --- which is mean the summer coast

# %%
resort = Hbook[(Hbook["hotel"] == "Resort Hotel") & (Hbook["is_canceled"] == 0)]
city = Hbook[(Hbook["hotel"] == "City Hotel") & (Hbook["is_canceled"])]

# %%
resort
# Out:
#               hotel  is_canceled  lead_time  arrival_date_year  \
# 0      Resort Hotel            0        342               2015
# 1      Resort Hotel            0        737               2015
# 2      Resort Hotel            0          7               2015
# 3      Resort Hotel            0         13               2015
# 4      Resort Hotel            0         14               2015
# ...             ...          ...        ...                ...
# 40055  Resort Hotel            0        212               2017
# 40056  Resort Hotel            0        169               2017
# 40057  Resort Hotel            0        204               2017
# 40058  Resort Hotel            0        211               2017
# 40059  Resort Hotel            0        161               2017
#
#       arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 0                   July                        27                          1
# ...

# %%
resort_hotel =resort.groupby(['arrival_date_month'])['adr'].mean().reset_index()
resort_hotel
# Out:
#    arrival_date_month         adr
# 0               April   75.867816
# 1              August  181.205892
# 2            December   68.322236
# 3            February   54.147478
# 4             January   48.708919
# 5                July  150.122528
# 6                June  107.921869
# 7               March   57.012487
# 8                 May   76.657558
# 9            November   48.681640
# 10            October   61.727505
# 11          September   96.416860

# %%
city_hotel =city.groupby(['arrival_date_month'])['adr'].mean().reset_index()
city_hotel
# Out:
#    arrival_date_month         adr
# 0               April  110.550823
# 1              August  109.105805
# 2            December   90.159149
# 3            February   83.323782
# 4             January   83.341309
# 5                July  103.748581
# 6                June  120.772560
# 7               March   96.862557
# 8                 May  123.133622
# 9            November   90.616508
# 10            October   97.623577
# 11          September  106.426730

# %%
final=resort_hotel.merge(city_hotel,on='arrival_date_month')
final.columns=['month','price_for_resort','price_for_city_hotel']
final
# Out:
#         month  price_for_resort  price_for_city_hotel
# 0       April         75.867816            110.550823
# 1      August        181.205892            109.105805
# 2    December         68.322236             90.159149
# 3    February         54.147478             83.323782
# 4     January         48.708919             83.341309
# 5        July        150.122528            103.748581
# 6        June        107.921869            120.772560
# 7       March         57.012487             96.862557
# 8         May         76.657558            123.133622
# 9    November         48.681640             90.616508
# 10    October         61.727505             97.623577
# 11  September         96.416860            106.426730

# %%
#for that code iwas install it from cmd 
## pip3 install sort-dataframeby-monthorweek

import sort_dataframeby_monthorweek as sd
final=sd.Sort_Dataframeby_Month(df=final,monthcolumnname='month')
final
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [12], in <cell line: 4>()
#       1 #for that code iwas install it from cmd
#       2 ## pip3 install sort-dataframeby-monthorweek
# ----> 4 import sort_dataframeby_monthorweek as sd
#       5 final=sd.Sort_Dataframeby_Month(df=final,monthcolumnname='month')
#       6 final
#
# ModuleNotFoundError: No module named 'sort_dataframeby_monthorweek'

# %%
Hbook['reserved_room_type'].unique()
# Out:
# array(['C', 'A', 'D', 'E', 'G', 'F', 'H', 'L', 'P', 'B'], dtype=object)

# %%
Hbook["adr_Updated"]=Hbook["adr"]/(Hbook["adults"]+Hbook["children"])
Hbook
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
prices = Hbook[['hotel', 'reserved_room_type', 'adr_Updated']].sort_values('reserved_room_type')
prices
# Out:
#               hotel reserved_room_type  adr_Updated
# 59694    City Hotel                  A        110.0
# 74263    City Hotel                  A         31.4
# 74262    City Hotel                  A         31.4
# 74261    City Hotel                  A         31.4
# 74260    City Hotel                  A         31.4
# ...             ...                ...          ...
# 61245    City Hotel                  P          NaN
# 61244    City Hotel                  P          NaN
# 4127   Resort Hotel                  P          NaN
# 65908    City Hotel                  P          NaN
# 9376   Resort Hotel                  P          NaN
#
# [119390 rows x 3 columns]

# %%
## to get the room price orf resorthotel

# %%
Hbook['adr_Updated']=Hbook['adr']/(Hbook['adults'] +Hbook['children'])
valid_guest = Hbook.loc[Hbook['is_canceled'] == 0]
prices = valid_guest[['hotel', 'reserved_room_type', 'adr_Updated']].sort_values('reserved_room_type')


plt.figure(figsize=(12, 8))
sns.boxplot(x="reserved_room_type",
            y="adr_Updated",
            hue="hotel",
            Hbook=prices
           )
plt.title('Price of room types per night and person', fontsize=16)
plt.xlabel('Room type', fontsize=16)
plt.ylabel('Price [EUR]', fontsize=16)


plt.yline(0, 160)
plt.show()
# Out:
#   File <tokenize>:11
#     )
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
## to get the room price orf hotelcity

# %%
prices_C=prices[prices['reserved_room_type']=='C']
prices_C
# Out:
#               hotel reserved_room_type  adr_Updated
# 25853  Resort Hotel                  C    82.500000
# 26926  Resort Hotel                  C    60.250000
# 26108  Resort Hotel                  C    49.125000
# 26861  Resort Hotel                  C   162.000000
# 26535  Resort Hotel                  C    43.262500
# ...             ...                ...          ...
# 27439  Resort Hotel                  C    52.790000
# 29232  Resort Hotel                  C    29.666667
# 31571  Resort Hotel                  C    91.750000
# 27407  Resort Hotel                  C    85.215000
# 27233  Resort Hotel                  C    58.250000
#
# [624 rows x 3 columns]

# %%
### That code to compareson for two kind's room price
####

# %%
prices_City=prices_C[prices_C['hotel']=='City Hotel']
prices_Resort=prices_C[prices_C['hotel']=='Resort Hotel']
prices_Resort
# Out:
#               hotel reserved_room_type  adr_Updated
# 25853  Resort Hotel                  C    82.500000
# 26926  Resort Hotel                  C    60.250000
# 26108  Resort Hotel                  C    49.125000
# 26861  Resort Hotel                  C   162.000000
# 26535  Resort Hotel                  C    43.262500
# ...             ...                ...          ...
# 27439  Resort Hotel                  C    52.790000
# 29232  Resort Hotel                  C    29.666667
# 31571  Resort Hotel                  C    91.750000
# 27407  Resort Hotel                  C    85.215000
# 27233  Resort Hotel                  C    58.250000
#
# [615 rows x 3 columns]

# %%
prices_City
# Out:
#              hotel reserved_room_type  adr_Updated
# 99432   City Hotel                  C         65.0
# 99431   City Hotel                  C         65.0
# 111027  City Hotel                  C          NaN
# 80557   City Hotel                  C         18.5
# 44693   City Hotel                  C         65.0
# 119278  City Hotel                  C        104.0
# 101137  City Hotel                  C         55.0
# 82508   City Hotel                  C          0.0
# 82509   City Hotel                  C          0.0

# %%
prices_Resort.describe()
# Out:
#        adr_Updated
# count   615.000000
# mean     50.549085
# std      27.821397
# min       0.000000
# 25%      31.000000
# 50%      49.000000
# 75%      65.562500
# max     171.000000

# %%
prices_City.describe()
# Out:
#        adr_Updated
# count      8.00000
# mean      46.56250
# std       36.86601
# min        0.00000
# 25%       13.87500
# 50%       60.00000
# 75%       65.00000
# max      104.00000

# %% [markdown]
# # After That we will start (( EDA )) for this project

# %% [markdown]
# # Q1 What is the type of Hotels preferd for people
# # Q2 percentage of cancelation type of hotels
# # Q3 most counterys people came from
